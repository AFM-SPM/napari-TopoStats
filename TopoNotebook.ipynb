# %%
import napari
from skimage.io import imread
import numpy
import copy
# Out:
# Running cells with 'c:\Program Files\Python39\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
viewer = napari.Viewer()
# Out:
# Running cells with 'c:\Program Files\Python39\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
original = imread("H:\\NapariWorkshop\\mesh_3D_stack.tif")
viewer.add_image(original)
# Out:
# Running cells with 'c:\Program Files\Python39\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
numslices = 256

# %%
shape = original.shape
shape[0] = numslices
stacked = numpy.empty(shape)
# Out:
# Running cells with 'c:\Program Files\Python39\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
for z in range(0, numslices):
	stacked[z,:,:] = ((original[0,:,:] > z) * 0) + z
# Out:
# (255, 520, 520)

# %%
for z in range(0, shape[0]):
	quickmesh[z,:,:] = (mesh[z,:,:]/255) * z

# %%
viewer.add_image(mesh)
viewer.add_image(quickmesh, name='quickmesh', colormap='inferno')
# Out:
# <Image layer 'slowmesh' at 0x1e00e8a4850>
